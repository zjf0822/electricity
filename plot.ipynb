# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_columns = ['id', 'k1k2', 'locks_signal', 'emergency_signal', 'access_signal', 'THDV_M', 'THDI_M', 'label']
# 读入数据
train = pd.read_csv("/home/zhoujifa/competition/baidu_elecrticity/data_train.csv", names=train_columns)

# %%
plt.hist(train['k1k2'], 100)
plt.show()

# %%
t = train.loc[(train.label == 1), ['k1k2']]
plt.hist(t.values, 1000)
plt.show()

# %%
t = train.loc[(train.label == 0), ['k1k2']]
plt.hist(t.values, 1000)
plt.show()

# %%
plt.hist(train['locks_signal'], 100)
plt.show()

# %%
t = train.loc[(train.label == 0), ['locks_signal']]
plt.hist(t.values, 1000)
plt.show()

# %%
t = train.loc[(train.label == 1), ['locks_signal']]
plt.hist(t.values, 1000)
plt.show()

# %%
plt.hist(train['emergency_signal'], 100)
plt.show()

# %%
t = train.loc[(train.label == 1), ['emergency_signal']]
plt.hist(t.values, 1000)
plt.show()

# %%
t = train.loc[(train.label == 0), ['emergency_signal']]
plt.hist(t.values, 1000)
plt.show()

# %%
plt.hist(train['access_signal'], 100)
plt.show()

# %%
t = train.loc[(train.label == 0), ['access_signal']]
plt.hist(t.values, 1000)
plt.show()

# %%
t = train.loc[(train.label == 1), ['access_signal']]
plt.hist(t.values, 1000)
plt.show()

# %%
plt.hist(train['THDV_M'], 1000)
plt.show()

# %%
t = train.loc[(train.label == 1), ['THDV_M']]
plt.hist(t.values, 1000)
plt.show()

# %%
t = train.loc[(train.label == 0), ['THDV_M']]
plt.hist(t.values, 1000)
plt.show()

# %%
plt.hist(train['THDI_M'], 1000)
plt.show()
